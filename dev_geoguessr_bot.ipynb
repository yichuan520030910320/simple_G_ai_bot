# %%
from io import BytesIO
import os
import dotenv
import base64
import pyautogui
import matplotlib.pyplot as plt
import math
from time import time, sleep
from typing import Tuple, List  
from PIL import Image
import yaml

from langchain_core.messages import HumanMessage, BaseMessage
from langchain_openai import ChatOpenAI
from langchain_anthropic import ChatAnthropic
from langchain_google_genai import ChatGoogleGenerativeAI

dotenv.load_dotenv()
# Out:
# /Users/yichuan/Desktop/code/geogusser/simple-G/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# True

# %%
with open("screen_regions.yaml") as f:
    screen_regions = yaml.safe_load(f)

screen_regions
# Out:
# {'confirm_button_1': [1676, 1047],
#  'hobart_1': [1763, 866],
#  'kodiak_1': [1336, 701],
#  'map_bot_right_1': [1886, 1014],
#  'map_top_left_1': [1247, 551],
#  'next_round_button': [1204, 994],
#  'screen_bot_right': [1916, 1076],
#  'screen_top_left': [496, 148]}

# %%
from geoguessr_bot import GeoBot

bot = GeoBot(screen_regions=screen_regions)

bot.screen_xywh
# Out:
# (496, 148, 1420, 928)

# %%
screenshot = pyautogui.screenshot(region=bot.screen_xywh)  
plt.imshow(screenshot)
print(bot.map_w, bot.map_h)
plt.plot(bot.screen_w-50, bot.screen_h-80, 'ro')

plt.show()
# Out:
# 639 463

# %%
minimap = pyautogui.screenshot(region=bot.minimap_xywh)
plt.imshow(minimap)
plt.plot(bot.hobart_x-bot.map_x, bot.hobart_y-bot.map_y, 'ro')
plt.plot(bot.kodiak_x-bot.map_x, bot.kodiak_y-bot.map_y, 'ro')
        # pyautogui.moveTo(self.map_x+self.map_w-30, self.map_y+self.map_h-30, duration=0.5)
# plot 
print(bot.map_x, bot.map_y, bot.map_w, bot.map_h)
print(bot.map_x+bot.map_w-30, bot.map_y+bot.map_h-30)
# plt.plot(bot.map_x+bot.map_w, bot.map_y+bot.map_h, 'ro')

plt.show()
# Out:
# 1247 551 639 463
# 1856 984
